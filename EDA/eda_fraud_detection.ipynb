# %%
# Loading data set for performing EDA on it:

import pandas as pd

file_path = "/home/omkar/Omkar Pawar/Data Science/Projects/Insurance Fraud Detection/Data/insuranceFraud.csv"

df = pd.read_csv(file_path)

# %%
df.head(20)
# Out:
#     months_as_customer  age  policy_number policy_bind_date policy_state
# 0                  328   48         521585       10/17/2014           OH  \
# 1                  228   42         342868        6/27/2006           IN
# 2                  134   29         687698         9/6/2000           OH
# 3                  256   41         227811        5/25/1990           IL
# 4                  228   44         367455         6/6/2014           IL
# 5                  256   39         104594       10/12/2006           OH
# 6                  137   34         413978         6/4/2000           IN
# 7                  165   37         429027         2/3/1990           IL
# 8                   27   33         485665         2/5/1997           IL
# 9                  212   42         636550        7/25/2011           IL
# 10                 235   42         543610        5/26/2002           OH
# 11                 447   61         214618        5/29/1999           OH
# ...

# %% [markdown]
# ---------

# %%
# In feature police_report_available the are `?` (question marks) which needs to be replaced by `NaN`.
df["police_report_available"].unique()
# Out:
# array(['YES', '?', 'NO'], dtype=object)

# %%
# Importing Numpy as np
import numpy as np

# %%
df.replace('?', np.NaN, inplace= True)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state
# 0                   328   48         521585       10/17/2014           OH  \
# 1                   228   42         342868        6/27/2006           IN
# 2                   134   29         687698         9/6/2000           OH
# 3                   256   41         227811        5/25/1990           IL
# 4                   228   44         367455         6/6/2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851        7/16/1991           OH
# 996                 285   41         186934         1/5/2014           IL
# 997                 130   34         918516        2/17/2003           OH
# 998                 458   62         533940       11/18/2011           IL
# 999                 456   60         556080       11/11/1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit
# ...

# %% [markdown]
# ---------

# %%
# Need to Remove unnecessary features which do not contribute in prediction:

col_to_remove = ['policy_number', '']
